# %%
# %%capture
# !apt install python-opengl
# !apt install ffmpeg
# !apt install xvfb
# !pip3 install pyvirtualdisplay

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %%
# Install the specific setuptools version required to install the dependencies
# !pip install setuptools==65.5.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting setuptools==65.5.0
#   Downloading setuptools-65.5.0-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 61.8 MB/s eta 0:00:00
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 67.7.2
#     Uninstalling setuptools-67.7.2:
#       Successfully uninstalled setuptools-67.7.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# cvxpy 1.3.1 requires setuptools>65.5.1, but you have setuptools 65.5.0 which is incompatible.
# Successfully installed setuptools-65.5.0

# %%
# !pip install -r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting stable-baselines3[extra]
#   Downloading stable_baselines3-1.8.0-py3-none-any.whl (174 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.5/174.5 kB 14.2 MB/s eta 0:00:00
# Collecting huggingface_sb3
#   Downloading huggingface_sb3-2.2.4-py3-none-any.whl (9.4 kB)
# Collecting panda_gym==2.0.0
#   Downloading panda_gym-2.0.0-py3-none-any.whl (26 kB)
# Collecting pyglet==1.5.1
#   Downloading pyglet-1.5.1-py2.py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 76.2 MB/s eta 0:00:00
# Requirement already satisfied: gym in /usr/local/lib/python3.10/dist-packages (from panda_gym==2.0.0->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 3)) (0.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from panda_gym==2.0.0->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 3)) (1.10.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from panda_gym==2.0.0->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 3)) (1.22.4)
# Collecting pybullet
#   Downloading pybullet-3.2.5.tar.gz (80.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.5/80.5 MB 19.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting importlib-metadata~=4.13
#   Downloading importlib_metadata-4.13.0-py3-none-any.whl (23 kB)
# Collecting gym
#   Downloading gym-0.21.0.tar.gz (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 86.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (2.0.0+cu118)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (3.7.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (1.5.3)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (2.2.1)
# Collecting autorom[accept-rom-license]~=0.6.0
#   Downloading AutoROM-0.6.1-py3-none-any.whl (9.4 kB)
# Collecting ale-py==0.7.4
#   Downloading ale_py-0.7.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 52.5 MB/s eta 0:00:00
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (13.3.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (8.4.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (4.7.0.72)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (5.9.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (4.65.0)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (2.12.2)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from ale-py==0.7.4->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (5.12.0)
# Requirement already satisfied: pyyaml~=6.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 2)) (6.0)
# Requirement already satisfied: wasabi in /usr/local/lib/python3.10/dist-packages (from huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 2)) (1.1.1)
# Collecting huggingface-hub~=0.8
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 28.7 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (2.27.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (8.1.3)
# Collecting AutoROM.accept-rom-license
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 50.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 2)) (2023.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 2)) (3.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 2)) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 2)) (23.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata~=4.13->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (3.15.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (0.7.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (1.54.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (0.40.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (65.5.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (1.0.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (2.3.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (3.4.3)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (3.20.3)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (1.4.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (1.8.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (3.1.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (1.11.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (2.0.0)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.11->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (16.0.2)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.11->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (3.25.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (4.39.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (1.0.7)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (2022.7.1)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (2.14.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (4.9)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (1.16.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (0.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (1.3.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (0.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (2.0.12)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt (line 1)) (3.2.2)
# Building wheels for collected packages: gym, pybullet, AutoROM.accept-rom-license
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Building wheel for gym (setup.py) ... error
#   ERROR: Failed building wheel for gym
#   Running setup.py clean for gym
#   Building wheel for pybullet (setup.py) ... done
#   Created wheel for pybullet: filename=pybullet-3.2.5-cp310-cp310-linux_x86_64.whl size=101452767 sha256=b7dcfd9530541096b731bf8d5def21c542369e09753e72ab297b3385d2a6b234
#   Stored in directory: /root/.cache/pip/wheels/6b/fa/1a/c315a5133f0c9bf202a6daa5d70891120e7fe403e06e3407cc
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.6.1-py3-none-any.whl size=446676 sha256=51e4d87203e1465e042a666ef5c29b9ba083e9f52f1e8ab1ec743eb8da5d94da
#   Stored in directory: /root/.cache/pip/wheels/6b/1b/ef/a43ff1a2f1736d5711faa1ba4c1f61be1131b8899e6a057811
# Successfully built pybullet AutoROM.accept-rom-license
# Failed to build gym
# Installing collected packages: pyglet, pybullet, importlib-metadata, gym, ale-py, panda_gym, huggingface-hub, AutoROM.accept-rom-license, autorom, huggingface_sb3, stable-baselines3
#   Attempting uninstall: gym
#     Found existing installation: gym 0.25.2
#     Uninstalling gym-0.25.2:
#       Successfully uninstalled gym-0.25.2
#   Running setup.py install for gym ... done
#   DEPRECATION: gym was installed using the legacy 'setup.py install' method, because a wheel could not be built for it. pip 23.1 will enforce this behaviour change. A possible replacement is to fix the wheel build issue reported above. Discussion can be found at https://github.com/pypa/pip/issues/8368
# Successfully installed AutoROM.accept-rom-license-0.6.1 ale-py-0.7.4 autorom-0.6.1 gym-0.21.0 huggingface-hub-0.14.1 huggingface_sb3-2.2.4 importlib-metadata-4.13.0 panda_gym-2.0.0 pybullet-3.2.5 pyglet-1.5.1 stable-baselines3-1.8.0

# %%
import pybullet_envs
import panda_gym
import gym

import os

from huggingface_sb3 import load_from_hub, package_to_hub

from stable_baselines3 import A2C
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from stable_baselines3.common.env_util import make_vec_env

from huggingface_hub import notebook_login

# %%
import gym

env_id = "PandaReachDense-v2"
env = make_vec_env(env_id, n_envs=4)

# %%
# 3
env = VecNormalize(env, norm_obs=True, norm_reward=False, clip_obs=10.)

# 4
model = A2C(policy = "MultiInputPolicy",
            env = env,
            verbose=1)
# 5
model.learn(8_000_000)
# Out:
# Streaming output truncated to the last 5000 lines.
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 372300   |
# |    time_elapsed       | 18446    |
# |    total_timesteps    | 7446000  |
# | train/                |          |
# |    entropy_loss       | 6.17     |
# |    explained_variance | 0.99     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 372299   |
# |    policy_loss        | -0.253   |
# |    std                | 0.0311   |
# |    value_loss         | 0.00705  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.14    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 372400   |
# |    time_elapsed       | 18451    |
# |    total_timesteps    | 7448000  |
# | train/                |          |
# |    entropy_loss       | 6.16     |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 372399   |
# |    policy_loss        | -0.169   |
# |    std                | 0.0311   |
# |    value_loss         | 0.00599  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.22    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 372500   |
# |    time_elapsed       | 18456    |
# |    total_timesteps    | 7450000  |
# | train/                |          |
# |    entropy_loss       | 6.15     |
# |    explained_variance | 0.996    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 372499   |
# |    policy_loss        | -0.139   |
# |    std                | 0.0313   |
# |    value_loss         | 0.0046   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.5     |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 372600   |
# |    time_elapsed       | 18460    |
# |    total_timesteps    | 7452000  |
# | train/                |          |
# |    entropy_loss       | 6.13     |
# |    explained_variance | 0.997    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 372599   |
# |    policy_loss        | -0.76    |
# |    std                | 0.0315   |
# |    value_loss         | 0.0325   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.34    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 372700   |
# |    time_elapsed       | 18465    |
# |    total_timesteps    | 7454000  |
# | train/                |          |
# |    entropy_loss       | 6.14     |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 372699   |
# |    policy_loss        | -0.239   |
# |    std                | 0.0314   |
# |    value_loss         | 0.00796  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.37    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 372800   |
# |    time_elapsed       | 18470    |
# |    total_timesteps    | 7456000  |
# | train/                |          |
# |    entropy_loss       | 6.12     |
# |    explained_variance | 0.997    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 372799   |
# |    policy_loss        | 0.184    |
# |    std                | 0.0315   |
# |    value_loss         | 0.00441  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.37    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 372900   |
# |    time_elapsed       | 18474    |
# |    total_timesteps    | 7458000  |
# | train/                |          |
# |    entropy_loss       | 6.13     |
# |    explained_variance | 0.993    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 372899   |
# |    policy_loss        | 0.175    |
# |    std                | 0.0315   |
# |    value_loss         | 0.0243   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.27    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 373000   |
# |    time_elapsed       | 18479    |
# |    total_timesteps    | 7460000  |
# | train/                |          |
# |    entropy_loss       | 6.13     |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 372999   |
# |    policy_loss        | 0.334    |
# |    std                | 0.0315   |
# |    value_loss         | 0.00556  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.23    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 373100   |
# |    time_elapsed       | 18484    |
# |    total_timesteps    | 7462000  |
# | train/                |          |
# |    entropy_loss       | 6.12     |
# |    explained_variance | 0.995    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 373099   |
# |    policy_loss        | -0.271   |
# |    std                | 0.0315   |
# |    value_loss         | 0.0149   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.31    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 373200   |
# |    time_elapsed       | 18488    |
# |    total_timesteps    | 7464000  |
# | train/                |          |
# |    entropy_loss       | 6.14     |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 373199   |
# |    policy_loss        | 0.169    |
# |    std                | 0.0313   |
# |    value_loss         | 0.0077   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.3     |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 373300   |
# |    time_elapsed       | 18493    |
# |    total_timesteps    | 7466000  |
# | train/                |          |
# |    entropy_loss       | 6.14     |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 373299   |
# |    policy_loss        | -0.0346  |
# |    std                | 0.0313   |
# |    value_loss         | 0.00468  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.45    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 373400   |
# |    time_elapsed       | 18498    |
# |    total_timesteps    | 7468000  |
# | train/                |          |
# |    entropy_loss       | 6.15     |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 373399   |
# |    policy_loss        | 0.224    |
# |    std                | 0.0312   |
# |    value_loss         | 0.00436  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.56    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 373500   |
# |    time_elapsed       | 18502    |
# |    total_timesteps    | 7470000  |
# | train/                |          |
# |    entropy_loss       | 6.16     |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 373499   |
# |    policy_loss        | -0.256   |
# |    std                | 0.0311   |
# |    value_loss         | 0.00505  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.48    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 373600   |
# |    time_elapsed       | 18507    |
# |    total_timesteps    | 7472000  |
# | train/                |          |
# |    entropy_loss       | 6.15     |
# |    explained_variance | 0.997    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 373599   |
# |    policy_loss        | -0.0365  |
# |    std                | 0.0312   |
# |    value_loss         | 0.00846  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.37    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 373700   |
# |    time_elapsed       | 18511    |
# |    total_timesteps    | 7474000  |
# | train/                |          |
# |    entropy_loss       | 6.15     |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 373699   |
# |    policy_loss        | 0.211    |
# |    std                | 0.0312   |
# |    value_loss         | 0.00634  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.26    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 373800   |
# |    time_elapsed       | 18516    |
# |    total_timesteps    | 7476000  |
# | train/                |          |
# |    entropy_loss       | 6.15     |
# |    explained_variance | 0.994    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 373799   |
# |    policy_loss        | 0.0231   |
# |    std                | 0.0312   |
# |    value_loss         | 0.0271   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.28    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 373900   |
# |    time_elapsed       | 18521    |
# |    total_timesteps    | 7478000  |
# | train/                |          |
# |    entropy_loss       | 6.14     |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 373899   |
# |    policy_loss        | -0.0595  |
# |    std                | 0.0314   |
# |    value_loss         | 0.0113   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.57    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 374000   |
# |    time_elapsed       | 18525    |
# |    total_timesteps    | 7480000  |
# | train/                |          |
# |    entropy_loss       | 6.14     |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 373999   |
# |    policy_loss        | -0.0341  |
# |    std                | 0.0314   |
# |    value_loss         | 0.0106   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.69    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 374100   |
# |    time_elapsed       | 18530    |
# |    total_timesteps    | 7482000  |
# | train/                |          |
# |    entropy_loss       | 6.13     |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 374099   |
# |    policy_loss        | -0.0196  |
# |    std                | 0.0313   |
# |    value_loss         | 0.00459  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.63    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 374200   |
# |    time_elapsed       | 18535    |
# |    total_timesteps    | 7484000  |
# | train/                |          |
# |    entropy_loss       | 6.14     |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 374199   |
# |    policy_loss        | 0.0833   |
# |    std                | 0.0314   |
# |    value_loss         | 0.00645  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.53    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 374300   |
# |    time_elapsed       | 18539    |
# |    total_timesteps    | 7486000  |
# | train/                |          |
# |    entropy_loss       | 6.15     |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 374299   |
# |    policy_loss        | 0.303    |
# |    std                | 0.0312   |
# |    value_loss         | 0.00825  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.56    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 374400   |
# |    time_elapsed       | 18544    |
# |    total_timesteps    | 7488000  |
# | train/                |          |
# |    entropy_loss       | 6.14     |
# |    explained_variance | 0.997    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 374399   |
# |    policy_loss        | 0.339    |
# |    std                | 0.0313   |
# |    value_loss         | 0.0236   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.35    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 374500   |
# |    time_elapsed       | 18549    |
# |    total_timesteps    | 7490000  |
# | train/                |          |
# |    entropy_loss       | 6.13     |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 374499   |
# |    policy_loss        | 0.662    |
# |    std                | 0.0315   |
# |    value_loss         | 0.0179   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.42    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 374600   |
# |    time_elapsed       | 18553    |
# |    total_timesteps    | 7492000  |
# | train/                |          |
# |    entropy_loss       | 6.14     |
# |    explained_variance | 0.996    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 374599   |
# |    policy_loss        | -0.206   |
# |    std                | 0.0313   |
# |    value_loss         | 0.00762  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.27    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 374700   |
# |    time_elapsed       | 18558    |
# |    total_timesteps    | 7494000  |
# | train/                |          |
# |    entropy_loss       | 6.14     |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 374699   |
# |    policy_loss        | -0.142   |
# |    std                | 0.0313   |
# |    value_loss         | 0.00623  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4       |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 374800   |
# |    time_elapsed       | 18562    |
# |    total_timesteps    | 7496000  |
# | train/                |          |
# |    entropy_loss       | 6.15     |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 374799   |
# |    policy_loss        | 0.0972   |
# |    std                | 0.0312   |
# |    value_loss         | 0.00187  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -3.74    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 374900   |
# |    time_elapsed       | 18567    |
# |    total_timesteps    | 7498000  |
# | train/                |          |
# |    entropy_loss       | 6.16     |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 374899   |
# |    policy_loss        | 0.125    |
# |    std                | 0.0311   |
# |    value_loss         | 0.0039   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.04    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 375000   |
# |    time_elapsed       | 18572    |
# |    total_timesteps    | 7500000  |
# | train/                |          |
# |    entropy_loss       | 6.14     |
# |    explained_variance | 0.994    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 374999   |
# |    policy_loss        | 0.138    |
# |    std                | 0.0313   |
# |    value_loss         | 0.00964  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.11    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 375100   |
# |    time_elapsed       | 18576    |
# |    total_timesteps    | 7502000  |
# | train/                |          |
# |    entropy_loss       | 6.14     |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 375099   |
# |    policy_loss        | -0.0801  |
# |    std                | 0.0314   |
# |    value_loss         | 0.00133  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.2     |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 375200   |
# |    time_elapsed       | 18581    |
# |    total_timesteps    | 7504000  |
# | train/                |          |
# |    entropy_loss       | 6.14     |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 375199   |
# |    policy_loss        | -0.132   |
# |    std                | 0.0313   |
# |    value_loss         | 0.00856  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.3     |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 375300   |
# |    time_elapsed       | 18586    |
# |    total_timesteps    | 7506000  |
# | train/                |          |
# |    entropy_loss       | 6.14     |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 375299   |
# |    policy_loss        | -0.473   |
# |    std                | 0.0313   |
# |    value_loss         | 0.0169   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.43    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 375400   |
# |    time_elapsed       | 18590    |
# |    total_timesteps    | 7508000  |
# | train/                |          |
# |    entropy_loss       | 6.12     |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 375399   |
# |    policy_loss        | -0.262   |
# |    std                | 0.0315   |
# |    value_loss         | 0.00577  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.27    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 375500   |
# |    time_elapsed       | 18595    |
# |    total_timesteps    | 7510000  |
# | train/                |          |
# |    entropy_loss       | 6.12     |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 375499   |
# |    policy_loss        | 0.123    |
# |    std                | 0.0315   |
# |    value_loss         | 0.0027   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.14    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 375600   |
# |    time_elapsed       | 18599    |
# |    total_timesteps    | 7512000  |
# | train/                |          |
# |    entropy_loss       | 6.1      |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 375599   |
# |    policy_loss        | 0.0429   |
# |    std                | 0.0316   |
# |    value_loss         | 0.00519  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.16    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 375700   |
# |    time_elapsed       | 18604    |
# |    total_timesteps    | 7514000  |
# | train/                |          |
# |    entropy_loss       | 6.11     |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 375699   |
# |    policy_loss        | -0.289   |
# |    std                | 0.0317   |
# |    value_loss         | 0.0041   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.38    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 375800   |
# |    time_elapsed       | 18609    |
# |    total_timesteps    | 7516000  |
# | train/                |          |
# |    entropy_loss       | 6.09     |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 375799   |
# |    policy_loss        | -0.437   |
# |    std                | 0.0318   |
# |    value_loss         | 0.0118   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.51    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 375900   |
# |    time_elapsed       | 18613    |
# |    total_timesteps    | 7518000  |
# | train/                |          |
# |    entropy_loss       | 6.09     |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 375899   |
# |    policy_loss        | 0.189    |
# |    std                | 0.0318   |
# |    value_loss         | 0.00302  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.44    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 376000   |
# |    time_elapsed       | 18618    |
# |    total_timesteps    | 7520000  |
# | train/                |          |
# |    entropy_loss       | 6.07     |
# |    explained_variance | 0.968    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 375999   |
# |    policy_loss        | -0.334   |
# |    std                | 0.032    |
# |    value_loss         | 0.00936  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.45    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 376100   |
# |    time_elapsed       | 18623    |
# |    total_timesteps    | 7522000  |
# | train/                |          |
# |    entropy_loss       | 6.07     |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 376099   |
# |    policy_loss        | -0.0533  |
# |    std                | 0.032    |
# |    value_loss         | 0.00327  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.38    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 376200   |
# |    time_elapsed       | 18627    |
# |    total_timesteps    | 7524000  |
# | train/                |          |
# |    entropy_loss       | 6.07     |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 376199   |
# |    policy_loss        | -0.251   |
# |    std                | 0.0321   |
# |    value_loss         | 0.0185   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.39    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 376300   |
# |    time_elapsed       | 18632    |
# |    total_timesteps    | 7526000  |
# | train/                |          |
# |    entropy_loss       | 6.07     |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 376299   |
# |    policy_loss        | 0.128    |
# |    std                | 0.0321   |
# |    value_loss         | 0.0101   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.37    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 376400   |
# |    time_elapsed       | 18636    |
# |    total_timesteps    | 7528000  |
# | train/                |          |
# |    entropy_loss       | 6.06     |
# |    explained_variance | 0.996    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 376399   |
# |    policy_loss        | 0.391    |
# |    std                | 0.0322   |
# |    value_loss         | 0.0101   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.36    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 376500   |
# |    time_elapsed       | 18641    |
# |    total_timesteps    | 7530000  |
# | train/                |          |
# |    entropy_loss       | 6.05     |
# |    explained_variance | 0.993    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 376499   |
# |    policy_loss        | -0.167   |
# |    std                | 0.0322   |
# |    value_loss         | 0.00858  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.5     |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 376600   |
# |    time_elapsed       | 18646    |
# |    total_timesteps    | 7532000  |
# | train/                |          |
# |    entropy_loss       | 6.05     |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 376599   |
# |    policy_loss        | 0.0747   |
# |    std                | 0.0323   |
# |    value_loss         | 0.0149   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.77    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 376700   |
# |    time_elapsed       | 18650    |
# |    total_timesteps    | 7534000  |
# | train/                |          |
# |    entropy_loss       | 6.06     |
# |    explained_variance | 0.962    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 376699   |
# |    policy_loss        | 0.236    |
# |    std                | 0.0321   |
# |    value_loss         | 0.0127   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.86    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 376800   |
# |    time_elapsed       | 18655    |
# |    total_timesteps    | 7536000  |
# | train/                |          |
# |    entropy_loss       | 6.07     |
# |    explained_variance | 0.937    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 376799   |
# |    policy_loss        | 0.523    |
# |    std                | 0.032    |
# |    value_loss         | 0.0158   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.68    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 376900   |
# |    time_elapsed       | 18660    |
# |    total_timesteps    | 7538000  |
# | train/                |          |
# |    entropy_loss       | 6.08     |
# |    explained_variance | 0.987    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 376899   |
# |    policy_loss        | 0.0968   |
# |    std                | 0.032    |
# |    value_loss         | 0.0213   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.67    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 377000   |
# |    time_elapsed       | 18665    |
# |    total_timesteps    | 7540000  |
# | train/                |          |
# |    entropy_loss       | 6.11     |
# |    explained_variance | 0.997    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 376999   |
# |    policy_loss        | 0.0787   |
# |    std                | 0.0316   |
# |    value_loss         | 0.00412  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.47    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 377100   |
# |    time_elapsed       | 18669    |
# |    total_timesteps    | 7542000  |
# | train/                |          |
# |    entropy_loss       | 6.11     |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 377099   |
# |    policy_loss        | -0.18    |
# |    std                | 0.0316   |
# |    value_loss         | 0.00409  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.59    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 377200   |
# |    time_elapsed       | 18674    |
# |    total_timesteps    | 7544000  |
# | train/                |          |
# |    entropy_loss       | 6.11     |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 377199   |
# |    policy_loss        | -0.545   |
# |    std                | 0.0316   |
# |    value_loss         | 0.0144   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.72    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 377300   |
# |    time_elapsed       | 18679    |
# |    total_timesteps    | 7546000  |
# | train/                |          |
# |    entropy_loss       | 6.1      |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 377299   |
# |    policy_loss        | 0.0177   |
# |    std                | 0.0317   |
# |    value_loss         | 0.0027   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.73    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 377400   |
# |    time_elapsed       | 18683    |
# |    total_timesteps    | 7548000  |
# | train/                |          |
# |    entropy_loss       | 6.11     |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 377399   |
# |    policy_loss        | 0.0328   |
# |    std                | 0.0316   |
# |    value_loss         | 0.00689  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.72    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 377500   |
# |    time_elapsed       | 18688    |
# |    total_timesteps    | 7550000  |
# | train/                |          |
# |    entropy_loss       | 6.11     |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 377499   |
# |    policy_loss        | -0.125   |
# |    std                | 0.0317   |
# |    value_loss         | 0.0119   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.54    |
# | time/                 |          |
# |    fps                | 404      |
# |    iterations         | 377600   |
# |    time_elapsed       | 18692    |
# |    total_timesteps    | 7552000  |
# | train/                |          |
# |    entropy_loss       | 6.12     |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 377599   |
# |    policy_loss        | 0.182    |
# |    std                | 0.0315   |
# |    value_loss         | 0.00589  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.4     |
# | time/                 |          |
# |    fps                | 404      |
# |    iterations         | 377700   |
# |    time_elapsed       | 18697    |
# |    total_timesteps    | 7554000  |
# | train/                |          |
# |    entropy_loss       | 6.14     |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 377699   |
# |    policy_loss        | -0.211   |
# |    std                | 0.0313   |
# |    value_loss         | 0.00678  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.41    |
# | time/                 |          |
# |    fps                | 404      |
# |    iterations         | 377800   |
# |    time_elapsed       | 18702    |
# |    total_timesteps    | 7556000  |
# | train/                |          |
# |    entropy_loss       | 6.12     |
# |    explained_variance | 0.994    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 377799   |
# |    policy_loss        | 0.75     |
# |    std                | 0.0315   |
# |    value_loss         | 0.0409   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.43    |
# | time/                 |          |
# |    fps                | 404      |
# |    iterations         | 377900   |
# |    time_elapsed       | 18706    |
# |    total_timesteps    | 7558000  |
# | train/                |          |
# |    entropy_loss       | 6.12     |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 377899   |
# |    policy_loss        | 0.204    |
# |    std                | 0.0315   |
# |    value_loss         | 0.00312  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.6     |
# | time/                 |          |
# |    fps                | 404      |
# |    iterations         | 378000   |
# |    time_elapsed       | 18711    |
# |    total_timesteps    | 7560000  |
# | train/                |          |
# |    entropy_loss       | 6.12     |
# |    explained_variance | 0.997    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 377999   |
# |    policy_loss        | -0.274   |
# |    std                | 0.0315   |
# |    value_loss         | 0.00866  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.72    |
# | time/                 |          |
# |    fps                | 404      |
# |    iterations         | 378100   |
# |    time_elapsed       | 18715    |
# |    total_timesteps    | 7562000  |
# | train/                |          |
# |    entropy_loss       | 6.12     |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 378099   |
# |    policy_loss        | -0.0847  |
# |    std                | 0.0315   |
# |    value_loss         | 0.00321  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.81    |
# | time/                 |          |
# |    fps                | 404      |
# |    iterations         | 378200   |
# |    time_elapsed       | 18720    |
# |    total_timesteps    | 7564000  |
# | train/                |          |
# |    entropy_loss       | 6.12     |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 378199   |
# |    policy_loss        | -0.0941  |
# |    std                | 0.0315   |
# |    value_loss         | 0.00454  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.71    |
# | time/                 |          |
# |    fps                | 404      |
# |    iterations         | 378300   |
# |    time_elapsed       | 18725    |
# |    total_timesteps    | 7566000  |
# | train/                |          |
# |    entropy_loss       | 6.11     |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 378299   |
# |    policy_loss        | 0.342    |
# |    std                | 0.0316   |
# |    value_loss         | 0.0126   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.52    |
# | time/                 |          |
# |    fps                | 404      |
# |    iterations         | 378400   |
# |    time_elapsed       | 18729    |
# |    total_timesteps    | 7568000  |
# | train/                |          |
# |    entropy_loss       | 6.12     |
# |    explained_variance | 0.997    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 378399   |
# |    policy_loss        | 0.214    |
# |    std                | 0.0315   |
# |    value_loss         | 0.0127   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.39    |
# | time/                 |          |
# |    fps                | 404      |
# |    iterations         | 378500   |
# |    time_elapsed       | 18734    |
# |    total_timesteps    | 7570000  |
# | train/                |          |
# |    entropy_loss       | 6.12     |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 378499   |
# |    policy_loss        | 0.169    |
# |    std                | 0.0315   |
# |    value_loss         | 0.00829  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.47    |
# | time/                 |          |
# |    fps                | 404      |
# |    iterations         | 378600   |
# |    time_elapsed       | 18738    |
# |    total_timesteps    | 7572000  |
# | train/                |          |
# |    entropy_loss       | 6.14     |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 378599   |
# |    policy_loss        | 0.167    |
# |    std                | 0.0313   |
# |    value_loss         | 0.00298  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.7     |
# | time/                 |          |
# |    fps                | 404      |
# |    iterations         | 378700   |
# |    time_elapsed       | 18743    |
# |    total_timesteps    | 7574000  |
# | train/                |          |
# |    entropy_loss       | 6.15     |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 378699   |
# |    policy_loss        | -0.0416  |
# |    std                | 0.0312   |
# |    value_loss         | 0.00185  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.71    |
# | time/                 |          |
# |    fps                | 404      |
# |    iterations         | 378800   |
# |    time_elapsed       | 18748    |
# |    total_timesteps    | 7576000  |
# | train/                |          |
# |    entropy_loss       | 6.16     |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 378799   |
# |    policy_loss        | 0.099    |
# |    std                | 0.0311   |
# |    value_loss         | 0.00931  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.62    |
# | time/                 |          |
# |    fps                | 404      |
# |    iterations         | 378900   |
# |    time_elapsed       | 18752    |
# |    total_timesteps    | 7578000  |
# | train/                |          |
# |    entropy_loss       | 6.16     |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 378899   |
# |    policy_loss        | -0.319   |
# |    std                | 0.0311   |
# |    value_loss         | 0.0108   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.58    |
# | time/                 |          |
# |    fps                | 404      |
# |    iterations         | 379000   |
# |    time_elapsed       | 18757    |
# |    total_timesteps    | 7580000  |
# | train/                |          |
# |    entropy_loss       | 6.16     |
# |    explained_variance | 0.996    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 378999   |
# |    policy_loss        | 0.247    |
# |    std                | 0.0311   |
# |    value_loss         | 0.0138   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.59    |
# | time/                 |          |
# |    fps                | 404      |
# |    iterations         | 379100   |
# |    time_elapsed       | 18761    |
# |    total_timesteps    | 7582000  |
# | train/                |          |
# |    entropy_loss       | 6.17     |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 379099   |
# |    policy_loss        | 0.247    |
# |    std                | 0.031    |
# |    value_loss         | 0.00666  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.6     |
# | time/                 |          |
# |    fps                | 404      |
# |    iterations         | 379200   |
# |    time_elapsed       | 18766    |
# |    total_timesteps    | 7584000  |
# | train/                |          |
# |    entropy_loss       | 6.17     |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 379199   |
# |    policy_loss        | 0.0724   |
# |    std                | 0.031    |
# |    value_loss         | 0.00232  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.66    |
# | time/                 |          |
# |    fps                | 404      |
# |    iterations         | 379300   |
# |    time_elapsed       | 18771    |
# |    total_timesteps    | 7586000  |
# | train/                |          |
# |    entropy_loss       | 6.18     |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 379299   |
# |    policy_loss        | -0.0981  |
# |    std                | 0.0309   |
# |    value_loss         | 0.00255  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.85    |
# | time/                 |          |
# |    fps                | 404      |
# |    iterations         | 379400   |
# |    time_elapsed       | 18775    |
# |    total_timesteps    | 7588000  |
# | train/                |          |
# |    entropy_loss       | 6.17     |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 379399   |
# |    policy_loss        | -0.045   |
# |    std                | 0.0311   |
# |    value_loss         | 0.00467  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# ...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -5.76    |
# | time/                 |          |
# |    fps                | 405      |
# |    iterations         | 397700   |
# |    time_elapsed       | 19629    |
# |    total_timesteps    | 7954000  |
# | train/                |          |
# |    entropy_loss       | 6.24     |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 397699   |
# |    policy_loss        | -0.385   |
# |    std                | 0.0304   |
# |    value_loss         | 0.0137   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -5.84    |
# | time/                 |          |
# |    fps                | 405      |
# |    iterations         | 397800   |
# |    time_elapsed       | 19634    |
# |    total_timesteps    | 7956000  |
# | train/                |          |
# |    entropy_loss       | 6.22     |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 397799   |
# |    policy_loss        | 0.0209   |
# |    std                | 0.0305   |
# |    value_loss         | 0.00994  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -5.89    |
# | time/                 |          |
# |    fps                | 405      |
# |    iterations         | 397900   |
# |    time_elapsed       | 19639    |
# |    total_timesteps    | 7958000  |
# | train/                |          |
# |    entropy_loss       | 6.2      |
# |    explained_variance | 0.984    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 397899   |
# |    policy_loss        | 0.381    |
# |    std                | 0.0308   |
# |    value_loss         | 0.0147   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -5.97    |
# | time/                 |          |
# |    fps                | 405      |
# |    iterations         | 398000   |
# |    time_elapsed       | 19643    |
# |    total_timesteps    | 7960000  |
# | train/                |          |
# |    entropy_loss       | 6.19     |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 397999   |
# |    policy_loss        | 0.116    |
# |    std                | 0.0308   |
# |    value_loss         | 0.0232   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -5.69    |
# | time/                 |          |
# |    fps                | 405      |
# |    iterations         | 398100   |
# |    time_elapsed       | 19648    |
# |    total_timesteps    | 7962000  |
# | train/                |          |
# |    entropy_loss       | 6.19     |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 398099   |
# |    policy_loss        | -0.401   |
# |    std                | 0.0309   |
# |    value_loss         | 0.0245   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -5.61    |
# | time/                 |          |
# |    fps                | 405      |
# |    iterations         | 398200   |
# |    time_elapsed       | 19653    |
# |    total_timesteps    | 7964000  |
# | train/                |          |
# |    entropy_loss       | 6.18     |
# |    explained_variance | 0.995    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 398199   |
# |    policy_loss        | -0.0209  |
# |    std                | 0.031    |
# |    value_loss         | 0.016    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -5.62    |
# | time/                 |          |
# |    fps                | 405      |
# |    iterations         | 398300   |
# |    time_elapsed       | 19657    |
# |    total_timesteps    | 7966000  |
# | train/                |          |
# |    entropy_loss       | 6.18     |
# |    explained_variance | 0.995    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 398299   |
# |    policy_loss        | 1.29     |
# |    std                | 0.031    |
# |    value_loss         | 0.112    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -5.76    |
# | time/                 |          |
# |    fps                | 405      |
# |    iterations         | 398400   |
# |    time_elapsed       | 19662    |
# |    total_timesteps    | 7968000  |
# | train/                |          |
# |    entropy_loss       | 6.19     |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 398399   |
# |    policy_loss        | -0.559   |
# |    std                | 0.0309   |
# |    value_loss         | 0.019    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -5.76    |
# | time/                 |          |
# |    fps                | 405      |
# |    iterations         | 398500   |
# |    time_elapsed       | 19667    |
# |    total_timesteps    | 7970000  |
# | train/                |          |
# |    entropy_loss       | 6.18     |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 398499   |
# |    policy_loss        | -0.127   |
# |    std                | 0.031    |
# |    value_loss         | 0.0105   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -5.56    |
# | time/                 |          |
# |    fps                | 405      |
# |    iterations         | 398600   |
# |    time_elapsed       | 19671    |
# |    total_timesteps    | 7972000  |
# | train/                |          |
# |    entropy_loss       | 6.18     |
# |    explained_variance | 0.997    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 398599   |
# |    policy_loss        | 0.0588   |
# |    std                | 0.031    |
# |    value_loss         | 0.0201   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -5.42    |
# | time/                 |          |
# |    fps                | 405      |
# |    iterations         | 398700   |
# |    time_elapsed       | 19676    |
# |    total_timesteps    | 7974000  |
# | train/                |          |
# |    entropy_loss       | 6.17     |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 398699   |
# |    policy_loss        | 0.483    |
# |    std                | 0.031    |
# |    value_loss         | 0.0129   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -5.19    |
# | time/                 |          |
# |    fps                | 405      |
# |    iterations         | 398800   |
# |    time_elapsed       | 19680    |
# |    total_timesteps    | 7976000  |
# | train/                |          |
# |    entropy_loss       | 6.17     |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 398799   |
# |    policy_loss        | 0.156    |
# |    std                | 0.0311   |
# |    value_loss         | 0.00553  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -5.46    |
# | time/                 |          |
# |    fps                | 405      |
# |    iterations         | 398900   |
# |    time_elapsed       | 19685    |
# |    total_timesteps    | 7978000  |
# | train/                |          |
# |    entropy_loss       | 6.17     |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 398899   |
# |    policy_loss        | -0.108   |
# |    std                | 0.031    |
# |    value_loss         | 0.00419  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -5.81    |
# | time/                 |          |
# |    fps                | 405      |
# |    iterations         | 399000   |
# |    time_elapsed       | 19690    |
# |    total_timesteps    | 7980000  |
# | train/                |          |
# |    entropy_loss       | 6.17     |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 398999   |
# |    policy_loss        | -0.369   |
# |    std                | 0.031    |
# |    value_loss         | 0.0142   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -5.91    |
# | time/                 |          |
# |    fps                | 405      |
# |    iterations         | 399100   |
# |    time_elapsed       | 19694    |
# |    total_timesteps    | 7982000  |
# | train/                |          |
# |    entropy_loss       | 6.2      |
# |    explained_variance | 0.996    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399099   |
# |    policy_loss        | 0.585    |
# |    std                | 0.0308   |
# |    value_loss         | 0.0448   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -5.62    |
# | time/                 |          |
# |    fps                | 405      |
# |    iterations         | 399200   |
# |    time_elapsed       | 19699    |
# |    total_timesteps    | 7984000  |
# | train/                |          |
# |    entropy_loss       | 6.2      |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399199   |
# |    policy_loss        | -0.413   |
# |    std                | 0.0308   |
# |    value_loss         | 0.0158   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -5.26    |
# | time/                 |          |
# |    fps                | 405      |
# |    iterations         | 399300   |
# |    time_elapsed       | 19704    |
# |    total_timesteps    | 7986000  |
# | train/                |          |
# |    entropy_loss       | 6.21     |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399299   |
# |    policy_loss        | -0.0333  |
# |    std                | 0.0307   |
# |    value_loss         | 0.00215  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -5.12    |
# | time/                 |          |
# |    fps                | 405      |
# |    iterations         | 399400   |
# |    time_elapsed       | 19708    |
# |    total_timesteps    | 7988000  |
# | train/                |          |
# |    entropy_loss       | 6.19     |
# |    explained_variance | 0.996    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399399   |
# |    policy_loss        | 0.115    |
# |    std                | 0.0308   |
# |    value_loss         | 0.00936  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -5.43    |
# | time/                 |          |
# |    fps                | 405      |
# |    iterations         | 399500   |
# |    time_elapsed       | 19713    |
# |    total_timesteps    | 7990000  |
# | train/                |          |
# |    entropy_loss       | 6.22     |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399499   |
# |    policy_loss        | -0.00282 |
# |    std                | 0.0306   |
# |    value_loss         | 0.00878  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -5.52    |
# | time/                 |          |
# |    fps                | 405      |
# |    iterations         | 399600   |
# |    time_elapsed       | 19718    |
# |    total_timesteps    | 7992000  |
# | train/                |          |
# |    entropy_loss       | 6.24     |
# |    explained_variance | 0.983    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399599   |
# |    policy_loss        | 0.458    |
# |    std                | 0.0303   |
# |    value_loss         | 0.025    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -5.54    |
# | time/                 |          |
# |    fps                | 405      |
# |    iterations         | 399700   |
# |    time_elapsed       | 19722    |
# |    total_timesteps    | 7994000  |
# | train/                |          |
# |    entropy_loss       | 6.22     |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399699   |
# |    policy_loss        | -0.519   |
# |    std                | 0.0305   |
# |    value_loss         | 0.014    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -5.38    |
# | time/                 |          |
# |    fps                | 405      |
# |    iterations         | 399800   |
# |    time_elapsed       | 19727    |
# |    total_timesteps    | 7996000  |
# | train/                |          |
# |    entropy_loss       | 6.24     |
# |    explained_variance | 0.997    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399799   |
# |    policy_loss        | -0.184   |
# |    std                | 0.0303   |
# |    value_loss         | 0.00727  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -5.48    |
# | time/                 |          |
# |    fps                | 405      |
# |    iterations         | 399900   |
# |    time_elapsed       | 19732    |
# |    total_timesteps    | 7998000  |
# | train/                |          |
# |    entropy_loss       | 6.23     |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399899   |
# |    policy_loss        | -0.0585  |
# |    std                | 0.0304   |
# |    value_loss         | 0.0304   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -5.44    |
# | time/                 |          |
# |    fps                | 405      |
# |    iterations         | 400000   |
# |    time_elapsed       | 19736    |
# |    total_timesteps    | 8000000  |
# | train/                |          |
# |    entropy_loss       | 6.22     |
# |    explained_variance | 0.972    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399999   |
# |    policy_loss        | 0.681    |
# |    std                | 0.0305   |
# |    value_loss         | 0.0371   |
# ------------------------------------

# %%
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# 6
model_name = "a2c-PandaReachDense-v2"; 
model.save(model_name)
env.save("vec_normalize.pkl")

# 7
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize

# Load the saved statistics
eval_env = DummyVecEnv([lambda: gym.make("PandaReachDense-v2")])
eval_env = VecNormalize.load("vec_normalize.pkl", eval_env)

#  do not update them at test time
eval_env.training = False
# reward normalization is not needed at test time
eval_env.norm_reward = False

# Load the agent
model = A2C.load(model_name)

mean_reward, std_reward = evaluate_policy(model, eval_env)

print(f"Mean reward = {mean_reward:.2f} +/- {std_reward:.2f}")

# 8
package_to_hub(
    model=model,
    model_name=f"a2c-{env_id}",
    model_architecture="A2C",
    env_id=env_id,
    eval_env=eval_env,
    repo_id=f"DrishtiSharma/a2c-{env_id}", # TODO: Change the username
    commit_message="Initial commit",
)
# Out:
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Mean reward = -5.50 +/- 2.66
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to 1min.
# This is a work in progress: if you encounter a bug, please open an issue.
# /usr/local/lib/python3.10/dist-packages/panda_gym/pybullet.py:97: UserWarning: The use of the render method is not recommended when the environment has not been created with render=True. The rendering will probably be weird. Prefer making the environment with option `render=True`. For example: `env = gym.make('PandaReach-v2', render=True)`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/panda_gym/pybullet.py:97: UserWarning: The use of the render method is not recommended when the environment has not been created with render=True. The rendering will probably be weird. Prefer making the environment with option `render=True`. For example: `env = gym.make('PandaReach-v2', render=True)`.
#   warnings.warn(
# Saving video to /tmp/tmpytwlsasn/-step-0-to-step-1000.mp4
# Exception ignored in: <function VecVideoRecorder.__del__ at 0x7f5a939e70a0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/stable_baselines3/common/vec_env/vec_video_recorder.py", line 112, in __del__
#     self.close()
#   File "/usr/local/lib/python3.10/dist-packages/stable_baselines3/common/vec_env/vec_video_recorder.py", line 108, in close
#     VecEnvWrapper.close(self)
#   File "/usr/local/lib/python3.10/dist-packages/stable_baselines3/common/vec_env/base_vec_env.py", line 279, in close
#     return self.venv.close()
#   File "/usr/local/lib/python3.10/dist-packages/stable_baselines3/common/vec_env/base_vec_env.py", line 279, in close
#     return self.venv.close()
#   File "/usr/local/lib/python3.10/dist-packages/stable_baselines3/common/vec_env/dummy_vec_env.py", line 80, in close
#     env.close()
#   File "/usr/local/lib/python3.10/dist-packages/gym/core.py", line 298, in close
#     return self.env.close()
#   File "/usr/local/lib/python3.10/dist-packages/panda_gym/envs/core.py", line 279, in close
#     self.sim.close()
#   File "/usr/local/lib/python3.10/dist-packages/panda_gym/pybullet.py", line 59, in close
#     self.physics_client.disconnect()
# pybullet.error: Not connected to physics server.
# ℹ Pushing repo DrishtiSharma/a2c-PandaReachDense-v2 to the Hugging Face
# Hub
# Upload 4 LFS files:   0%|          | 0/4 [00:00<?, ?it/s]
# policy.optimizer.pth:   0%|          | 0.00/44.7k [00:00<?, ?B/s]
# policy.pth:   0%|          | 0.00/46.0k [00:00<?, ?B/s]
# vec_normalize.pkl:   0%|          | 0.00/2.39k [00:00<?, ?B/s]
# a2c-PandaReachDense-v2.zip:   0%|          | 0.00/108k [00:00<?, ?B/s]
# ℹ Your model is pushed to the Hub. You can view your model here:
# https://huggingface.co/DrishtiSharma/a2c-PandaReachDense-v2/tree/main/
# 'https://huggingface.co/DrishtiSharma/a2c-PandaReachDense-v2/tree/main/'

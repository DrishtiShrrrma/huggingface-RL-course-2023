# %%
# !git clone --branch aivsai https://github.com/huggingface/ml-agents
# Out:
# fatal: destination path 'ml-agents' already exists and is not an empty directory.

# %%
# %cd ml-agents
# !pip install -e ./ml-agents-envs
# !pip install -e ./ml-agents
# Out:
# /content/ml-agents
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/ml-agents/ml-agents-envs
#   Preparing metadata (setup.py) ... done
# ...
#   Attempting uninstall: mlagents-envs
#     Found existing installation: mlagents-envs 0.31.0.dev0
#     Can't uninstall 'mlagents-envs'. No files were found to uninstall.
#   Running setup.py develop for mlagents-envs
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/ml-agents/ml-agents
#   Preparing metadata (setup.py) ... done
# ...
#   Attempting uninstall: mlagents
#     Found existing installation: mlagents 0.31.0.dev0
#     Can't uninstall 'mlagents'. No files were found to uninstall.
#   Running setup.py develop for mlagents
# ...

# %%
# !mkdir ./trained-envs-executables
# Out:
# mkdir: cannot create directory ‘./trained-envs-executables’: File exists

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1zv3M95ZJTWHUVOWT6ckq_cm98nft8gdF' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1KuqBKYiXiIcU4kNMqEzhgypuFP5_45CL" -O ./trained-envs-executables/SoccerTwos.zip && rm -rf /tmp/cookies.txt
# Out:
# --2023-03-28 11:38:13--  https://docs.google.com/uc?export=download&confirm=t&id=1KuqBKYiXiIcU4kNMqEzhgypuFP5_45CL
# Resolving docs.google.com (docs.google.com)... 74.125.24.102, 74.125.24.101, 74.125.24.100, ...
# Connecting to docs.google.com (docs.google.com)|74.125.24.102|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-04-8c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/kpu84epv2nmanlhtfm336rskal9rd58n/1680003450000/09764732090272539193/*/1KuqBKYiXiIcU4kNMqEzhgypuFP5_45CL?e=download&uuid=9453614f-5d58-480f-a8a3-d9d2c53ffc27 [following]
# ...
# --2023-03-28 11:38:13--  https://doc-04-8c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/kpu84epv2nmanlhtfm336rskal9rd58n/1680003450000/09764732090272539193/*/1KuqBKYiXiIcU4kNMqEzhgypuFP5_45CL?e=download&uuid=9453614f-5d58-480f-a8a3-d9d2c53ffc27
# ...

# %%
# %%capture
# !unzip -d ./trained-envs-executables/ ./trained-envs-executables/SoccerTwos.zip

# %%
# !chmod -R 755 ./trained-envs-executables/SoccerTwos.x86_64

# %%
# !mlagents-learn /content/ml-agents/config/poca/SoccerTwos.yaml --env=./trained-envs-executables/SoccerTwos.x86_64 --run-id="SoccerTwos111" --no-graphics
# Out:
#             ┐  ╖
#         ╓╖╬│╡  ││╬╖╖
#     ╓╖╬│││││┘  ╬│││││╬╖
#  ╖╬│││││╬╜        ╙╬│││││╖╖                               ╗╗╗
#  ╬╬╬╬╖││╦╖        ╖╬││╗╣╣╣╬      ╟╣╣╬    ╟╣╣╣             ╜╜╜  ╟╣╣
#  ╬╬╬╬╬╬╬╬╖│╬╖╖╓╬╪│╓╣╣╣╣╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╒╣╣╖╗╣╣╣╗   ╣╣╣ ╣╣╣╣╣╣ ╟╣╣╖   ╣╣╣
#  ╬╬╬╬┐  ╙╬╬╬╬│╓╣╣╣╝╜  ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╣╙ ╙╣╣╣  ╣╣╣ ╙╟╣╣╜╙  ╫╣╣  ╟╣╣
#  ╬╬╬╬┐     ╙╬╬╣╣      ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣     ╣╣╣┌╣╣╜
#  ╬╬╬╜       ╬╬╣╣      ╙╝╣╣╬      ╙╣╣╣╗╖╓╗╣╣╣╜ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣╦╓    ╣╣╣╣╣
#  ╙   ╓╦╖    ╬╬╣╣   ╓╗╗╖            ╙╝╣╣╣╣╝╜   ╘╝╝╜   ╝╝╝  ╝╝╝   ╙╣╣╣    ╟╣╣╣
#    ╩╬╬╬╬╬╬╦╦╬╬╣╣╗╣╣╣╣╣╣╣╝                                             ╫╣╣╣╣
#       ╙╬╬╬╬╬╬╬╣╣╣╣╣╣╝╜
#           ╙╬╬╬╣╣╣╜
#              ╙
#
#  Version information:
#   ml-agents: 0.31.0.dev0,
#   ml-agents-envs: 0.31.0.dev0,
#   Communicator API: 1.5.0,
#   PyTorch: 1.11.0+cu102
# [INFO] Connected to Unity environment with package version 2.3.0-exp.3 and communication version 1.5.0
# ...

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# Token is valid.
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# !mlagents-push-to-hf --run-id="SoccerTwos" --local-dir="./results/SoccerTwos" --repo-id="DrishtiSharma/SoccerTwos-numlayers-8" --commit-message="SoccerTwos"
# Out:
# SoccerTwos
# DrishtiSharma/SoccerTwos-numlayers-8
# This function will create a model card and upload your SoccerTwos into HuggingFace Hub. This is a work in progress: If you encounter a bug, please send open an issue
# REPO NAME:  SoccerTwos-numlayers-8
# ORGANIZATION:  DrishtiSharma
# Cloning https://huggingface.co/DrishtiSharma/SoccerTwos-numlayers-8 into local empty directory.
# Upload file SoccerTwos/SoccerTwos-2499404.pt:   0% 1.00/27.1M [00:00<?, ?B/s]
# Upload file SoccerTwos/SoccerTwos-1499988.pt:   0% 1.00/27.1M [00:00<?, ?B/s]
#
# Upload file SoccerTwos/SoccerTwos-1999200.pt:   0% 1.00/27.1M [00:00<?, ?B/s]
#
#
# Upload file SoccerTwos/SoccerTwos-999306.pt:   0% 1.00/27.1M [00:00<?, ?B/s]
#
#
#
# Upload file SoccerTwos/events.out.tfevents.1679997937.9cf222c37ef5.2229.0:   0% 1.00/1.89M [00:00<?, ?B/s]
#
#
#
#
# Upload file SoccerTwos/SoccerTwos-2499404.onnx:   0% 1.00/1.68M [00:00<?, ?B/s]
#
#
#
#
#
# Upload file SoccerTwos.onnx:   0% 1.00/1.68M [00:00<?, ?B/s]
#
#
#
#
#
# ...
